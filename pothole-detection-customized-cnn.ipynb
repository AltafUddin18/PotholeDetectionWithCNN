# %% [markdown]
# ### **1. Import the Required Libraries**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### **2. Load the Image Training and Validation Datasets**

# %% [markdown]
# #### **i. Get the Image Dataset Paths**

# %%
train_dataset_path = '/kaggle/input/pothole-data/My_Dataset/train/'
validation_dataset_path = '/kaggle/input/pothole-data/My_Dataset/test/'

# %% [markdown]
# #### **ii. Load Image Datasets and Apply Augmentations**

# %% [markdown]
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 5075 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1021 images belonging to 2 classes.

# %% [markdown]
# #### **iii. Get the Label Mappings**

# %% [markdown]
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Plain
# 1 : Pothole

# %% [markdown]
# ### **3. Plotting Sample Training Images**

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ### **4. Training a CNN Model**

# %% [markdown]
# Since the training dataset is ready let's create a simple CNN Model to train on the image datasets

# %% [markdown]
# #### **i. Create a CNN Model**

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=256, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),

        Flatten(),

        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=128, activation='relu'),
        Dropout(0.5),
        Dense(units=2, activation='sigmoid')
    ])

    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 146, 146, 256)     19456
#
#  activation (Activation)     (None, 146, 146, 256)     0
#
#  max_pooling2d (MaxPooling2D  (None, 73, 73, 256)      0
#  )
#
#  batch_normalization (BatchN  (None, 73, 73, 256)      1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 69, 69, 128)       819328
#
#  activation_1 (Activation)   (None, 69, 69, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 34, 34, 128)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 34, 34, 128)      512
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        73792
#
#  activation_2 (Activation)   (None, 32, 32, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        18464
#
#  activation_3 (Activation)   (None, 14, 14, 32)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 7, 7, 32)         128
#  hNormalization)
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 256)               401664
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 1,367,778
# Trainable params: 1,366,818
# Non-trainable params: 960
# _________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model
plot_model(cnn_model, expand_nested=True, show_shapes=True, show_layer_names=False)

# %% [markdown]
# #### **ii. Defining Callbacks**

# %% [markdown]
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %% [markdown]
# #### **a. Reduce Learning Rate on Plateau**
#
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %% [markdown]
# #### **iii. Defining the Optimizer**

# %%
optimizer = Adamax(learning_rate=0.00001)

# %% [markdown]
# #### **iv. Compile the Model**

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# #### **v. Training the Model**

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=validation_generator,
                       verbose=2)
# Out:
# Epoch 1/50
# 159/159 - 131s - loss: 0.8819 - accuracy: 0.6327 - val_loss: 0.7983 - val_accuracy: 0.5015 - 131s/epoch - 822ms/step
# Epoch 2/50
# 159/159 - 61s - loss: 0.5950 - accuracy: 0.7604 - val_loss: 1.1554 - val_accuracy: 0.5015 - 61s/epoch - 382ms/step
# Epoch 3/50
# 159/159 - 60s - loss: 0.4448 - accuracy: 0.8240 - val_loss: 1.1809 - val_accuracy: 0.5132 - 60s/epoch - 378ms/step
# Epoch 4/50
# 159/159 - 60s - loss: 0.3553 - accuracy: 0.8646 - val_loss: 0.7903 - val_accuracy: 0.7062 - 60s/epoch - 378ms/step
# Epoch 5/50
# 159/159 - 60s - loss: 0.3060 - accuracy: 0.8857 - val_loss: 0.6152 - val_accuracy: 0.7610 - 60s/epoch - 377ms/step
# Epoch 6/50
# 159/159 - 61s - loss: 0.2588 - accuracy: 0.9062 - val_loss: 0.6809 - val_accuracy: 0.7620 - 61s/epoch - 381ms/step
# Epoch 7/50
# 159/159 - 59s - loss: 0.2212 - accuracy: 0.9232 - val_loss: 0.7405 - val_accuracy: 0.7640 - 59s/epoch - 374ms/step
# Epoch 8/50
# 159/159 - 60s - loss: 0.1950 - accuracy: 0.9360 - val_loss: 0.7351 - val_accuracy: 0.7796 - 60s/epoch - 376ms/step
# Epoch 9/50
# 159/159 - 60s - loss: 0.1773 - accuracy: 0.9444 - val_loss: 0.7729 - val_accuracy: 0.7777 - 60s/epoch - 380ms/step
# Epoch 10/50
# 159/159 - 60s - loss: 0.1648 - accuracy: 0.9503 - val_loss: 0.8146 - val_accuracy: 0.7747 - 60s/epoch - 378ms/step
# Epoch 11/50
# 159/159 - 60s - loss: 0.1562 - accuracy: 0.9486 - val_loss: 0.8474 - val_accuracy: 0.7747 - 60s/epoch - 378ms/step
# Epoch 12/50
# 159/159 - 60s - loss: 0.1373 - accuracy: 0.9574 - val_loss: 0.8098 - val_accuracy: 0.7835 - 60s/epoch - 377ms/step
# Epoch 13/50
# 159/159 - 60s - loss: 0.1319 - accuracy: 0.9604 - val_loss: 0.8158 - val_accuracy: 0.7875 - 60s/epoch - 377ms/step
# Epoch 14/50
# 159/159 - 60s - loss: 0.1323 - accuracy: 0.9624 - val_loss: 0.7794 - val_accuracy: 0.7982 - 60s/epoch - 375ms/step
# Epoch 15/50
# 159/159 - 60s - loss: 0.1227 - accuracy: 0.9647 - val_loss: 0.9117 - val_accuracy: 0.7796 - 60s/epoch - 378ms/step
# Epoch 16/50
# 159/159 - 60s - loss: 0.1184 - accuracy: 0.9671 - val_loss: 0.9190 - val_accuracy: 0.7865 - 60s/epoch - 378ms/step
# Epoch 17/50
# 159/159 - 60s - loss: 0.1177 - accuracy: 0.9700 - val_loss: 0.9570 - val_accuracy: 0.7777 - 60s/epoch - 377ms/step
# Epoch 18/50
# 159/159 - 59s - loss: 0.1011 - accuracy: 0.9732 - val_loss: 0.9787 - val_accuracy: 0.7767 - 59s/epoch - 373ms/step
# Epoch 19/50
# 159/159 - 59s - loss: 0.1139 - accuracy: 0.9720 - val_loss: 0.8562 - val_accuracy: 0.7982 - 59s/epoch - 373ms/step
# Epoch 20/50
# 159/159 - 60s - loss: 0.1135 - accuracy: 0.9689 - val_loss: 0.8843 - val_accuracy: 0.7953 - 60s/epoch - 375ms/step
# Epoch 21/50
# 159/159 - 60s - loss: 0.0871 - accuracy: 0.9779 - val_loss: 0.8863 - val_accuracy: 0.7992 - 60s/epoch - 378ms/step
# Epoch 22/50
# 159/159 - 60s - loss: 0.0945 - accuracy: 0.9756 - val_loss: 0.9200 - val_accuracy: 0.7894 - 60s/epoch - 377ms/step
# Epoch 23/50
# 159/159 - 60s - loss: 0.0896 - accuracy: 0.9773 - val_loss: 0.9968 - val_accuracy: 0.7835 - 60s/epoch - 375ms/step
# Epoch 24/50
# 159/159 - 60s - loss: 0.0943 - accuracy: 0.9766 - val_loss: 0.8580 - val_accuracy: 0.8071 - 60s/epoch - 376ms/step
# Epoch 25/50
# 159/159 - 60s - loss: 0.0880 - accuracy: 0.9785 - val_loss: 0.8933 - val_accuracy: 0.8002 - 60s/epoch - 379ms/step
# Epoch 26/50
# 159/159 - 61s - loss: 0.0958 - accuracy: 0.9779 - val_loss: 0.9670 - val_accuracy: 0.7943 - 61s/epoch - 381ms/step
# Epoch 27/50
# 159/159 - 60s - loss: 0.0962 - accuracy: 0.9762 - val_loss: 0.8360 - val_accuracy: 0.8022 - 60s/epoch - 380ms/step
# Epoch 28/50
# 159/159 - 62s - loss: 0.0859 - accuracy: 0.9795 - val_loss: 0.9221 - val_accuracy: 0.7953 - 62s/epoch - 388ms/step
# Epoch 29/50
# 159/159 - 65s - loss: 0.0849 - accuracy: 0.9787 - val_loss: 0.8885 - val_accuracy: 0.8051 - 65s/epoch - 411ms/step
# Epoch 30/50
# 159/159 - 63s - loss: 0.0912 - accuracy: 0.9762 - val_loss: 0.9246 - val_accuracy: 0.8022 - 63s/epoch - 396ms/step
# Epoch 31/50
# 159/159 - 62s - loss: 0.0877 - accuracy: 0.9793 - val_loss: 0.9600 - val_accuracy: 0.7933 - 62s/epoch - 393ms/step
# Epoch 32/50
# 159/159 - 63s - loss: 0.0791 - accuracy: 0.9819 - val_loss: 1.0030 - val_accuracy: 0.7933 - 63s/epoch - 397ms/step
# Epoch 33/50
# 159/159 - 62s - loss: 0.0946 - accuracy: 0.9787 - val_loss: 0.9093 - val_accuracy: 0.8041 - 62s/epoch - 392ms/step
# Epoch 34/50
# 159/159 - 62s - loss: 0.0783 - accuracy: 0.9831 - val_loss: 1.0004 - val_accuracy: 0.7914 - 62s/epoch - 388ms/step
# Epoch 35/50
# 159/159 - 61s - loss: 0.0893 - accuracy: 0.9789 - val_loss: 0.8848 - val_accuracy: 0.8022 - 61s/epoch - 386ms/step
# Epoch 36/50
# 159/159 - 60s - loss: 0.0854 - accuracy: 0.9803 - val_loss: 0.8029 - val_accuracy: 0.8110 - 60s/epoch - 377ms/step
# Epoch 37/50
# 159/159 - 60s - loss: 0.0860 - accuracy: 0.9793 - val_loss: 0.8104 - val_accuracy: 0.8149 - 60s/epoch - 376ms/step
# Epoch 38/50
# 159/159 - 60s - loss: 0.0690 - accuracy: 0.9848 - val_loss: 0.9215 - val_accuracy: 0.7992 - 60s/epoch - 375ms/step
# Epoch 39/50
# 159/159 - 60s - loss: 0.0766 - accuracy: 0.9793 - val_loss: 0.8857 - val_accuracy: 0.8100 - 60s/epoch - 380ms/step
# Epoch 40/50
# 159/159 - 60s - loss: 0.0762 - accuracy: 0.9803 - val_loss: 0.8879 - val_accuracy: 0.8129 - 60s/epoch - 379ms/step
# Epoch 41/50
# 159/159 - 59s - loss: 0.0850 - accuracy: 0.9807 - val_loss: 0.9833 - val_accuracy: 0.7953 - 59s/epoch - 371ms/step
# Epoch 42/50
# 159/159 - 60s - loss: 0.0788 - accuracy: 0.9844 - val_loss: 0.9327 - val_accuracy: 0.7992 - 60s/epoch - 375ms/step
# Epoch 43/50
# 159/159 - 61s - loss: 0.0755 - accuracy: 0.9840 - val_loss: 0.9527 - val_accuracy: 0.7973 - 61s/epoch - 385ms/step
# Epoch 44/50
# 159/159 - 60s - loss: 0.0725 - accuracy: 0.9825 - val_loss: 0.8486 - val_accuracy: 0.8149 - 60s/epoch - 380ms/step
# Epoch 45/50
# 159/159 - 60s - loss: 0.0779 - accuracy: 0.9829 - val_loss: 0.8856 - val_accuracy: 0.8159 - 60s/epoch - 378ms/step
# Epoch 46/50
# 159/159 - 60s - loss: 0.0702 - accuracy: 0.9848 - val_loss: 1.0343 - val_accuracy: 0.7904 - 60s/epoch - 377ms/step
# Epoch 47/50
# 159/159 - 61s - loss: 0.0741 - accuracy: 0.9827 - val_loss: 0.8673 - val_accuracy: 0.8178 - 61s/epoch - 381ms/step
# Epoch 48/50
# 159/159 - 59s - loss: 0.0777 - accuracy: 0.9827 - val_loss: 0.9550 - val_accuracy: 0.8031 - 59s/epoch - 371ms/step
# Epoch 49/50
# 159/159 - 60s - loss: 0.0683 - accuracy: 0.9829 - val_loss: 0.9083 - val_accuracy: 0.8110 - 60s/epoch - 379ms/step
# Epoch 50/50
# 159/159 - 61s - loss: 0.0787 - accuracy: 0.9833 - val_loss: 0.9206 - val_accuracy: 0.8090 - 61s/epoch - 382ms/step

# %% [markdown]
# ### **5. Plotting the Model Metrics**

# %% [markdown]
# #### **i. Plotting training and validation accuracy, loss and learning rate**

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10, 8))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### **6. Testing the Model on Test Set**

# %% [markdown]
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/kaggle/input/pothole-data/My_Dataset/test/'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 1021 images belonging to 2 classes.

# %% [markdown]
# ### **7. Model Prediction on the Test Dataset**

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 32/32 [==============================] - 3s 101ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 32/32 [==============================] - 3s 106ms/step - loss: 0.9206 - accuracy: 0.8090

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.9205853939056396
# Test Accuracy: 0.8090107440948486

# %% [markdown]
# The test loss and test accuracy is the same as validation loss and validation accuracy at the last step since the testing and validation datasets are same.

# %% [markdown]
# ### **8. Plotting the Classification Metrics**

# %% [markdown]
# ### **i. Confusion Matrix**

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#        Plain       1.00      0.62      0.76       509
#      Pothole       0.72      1.00      0.84       512
#
#     accuracy                           0.81      1021
#    macro avg       0.86      0.81      0.80      1021
# weighted avg       0.86      0.81      0.80      1021

# %% [markdown]
# ### **9. Wrong Predictions**
#
# Let's see where the model has given wrong predictions and what were the actual predictions on those images.

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
